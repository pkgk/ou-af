# %% [markdown]
# # Light example, use influence diagrams during problem diagnosis
#
#
# ### Actors:
# - system which via embeded influence diagram can help diagnosing problems in a system
# - repair specialist who needs to solve a problem that prevents normal operation of a system

# %% [markdown]
# Start of scenario is when a repair specialist is called in to help solve a problem at a user. The repair specialist brings a laptop containing a system that guides the steps. First step is to start the software.

# %% [markdown]
# ### starting the software

# %%
# imports
import os
import math
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from pylab import *
from IPython.display import display,HTML

# pyAgrum
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %%
# create influence diagram, load BIFXML file
diag = gum.InfluenceDiagram()
diag.loadBIFXML("lightv6.xml") 
gnb.showInfluenceDiagram(diag, size=80)

# %%
# RL1T1
diag.cpt("RL1T1")[{"HL1": "ok"}]          = [0.95, 0.05, 0.0]  # HL1:ok > RL1T1 likely not done
diag.cpt("RL1T1")[{"HL1": "broken"}]      = [0.4, 0.1, 0.5]  # HL1:broken > RL1T1 likely broken

# %%
gnb.flow.row(
    diag.cpt("HL1"),
    diag.cpt("CL1"),
    diag.cpt("RL1T1"),
    diag.utility("UL1T1")
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>HL1</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#a5d864;text-align:right;'>0.7000</td><td style='color:black;background-color:#d8a564;text-align:right;'>0.3000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>CL1</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>HL1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>on</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>off</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>ok</center></th><td style='color:black;background-color:#f28b64;text-align:right;'>0.1000</td><td style='color:black;background-color:#8bf264;text-align:right;'>0.9000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>broken</center></th><td style='color:black;background-color:#f88564;text-align:right;'>0.0500</td><td style='color:black;background-color:#85f864;text-align:right;'>0.9500</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>RL1T1</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>HL1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>not done</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>ok</center></th><td style='color:black;background-color:#85f864;text-align:right;'>0.9500</td><td style='color:black;background-color:#f88564;text-align:right;'>0.0500</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>broken</center></th><td style='color:black;background-color:#cbb264;text-align:right;'>0.4000</td><td style='color:black;background-color:#f28b64;text-align:right;'>0.1000</td><td style='color:black;background-color:#bfbf64;text-align:right;'>0.5000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UL1T1</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>HL1</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DL1T1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>1.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>2.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>3.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# </table></div>

# %%
display(HTML("<style>.container { width:100% !important; }</style>"))

# create inference without any evidence
ie = gum.ShaferShenoyLIMIDInference(diag) 
gnb.showInference(diag, engine=ie, evs={"DL1T1":1}, size=40)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
gnb.flow.row(
    ie.optimalDecision("DL1T1"), 
    ie.MEU()["mean"],
    ie.posterior("DL1T1"), 
    ie.posteriorUtility("DL1T1"), 
    ie.posteriorUtility("UL1T1"), 
    ie.posterior("UL1T1"),
    ie.posterior("HL1"),
    ie.posteriorUtility("HL1"),
    captions=[
        "optimaldecision DL1T1",
        "expected utility network",
        "posterior DL1T1",
        "posterior utility DL1T1",
        "posteriorUtility UL1T1",
        "posterior UL1T1",
        "posterior HL1",
        "posterior Utility HL1"
    ]
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>DL1T1</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>optimaldecision DL1T1</em></small></center></div><div class="floating-box">1.4<br><center><small><em>expected utility network</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>DL1T1</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>posterior DL1T1</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>DL1T1</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='text-align:right;'>0.0000</td><td style='text-align:right;'>1.4000</td></tr>
# </table><br><center><small><em>posterior utility DL1T1</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UL1T1</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>HL1</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DL1T1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>1.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>2.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>3.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>posteriorUtility UL1T1</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>HL1</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>DL1T1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#a5d864;text-align:right;'>0.7000</td><td style='color:black;background-color:#d8a564;text-align:right;'>0.3000</td></tr>
# </table><br><center><small><em>posterior UL1T1</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>HL1</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#a5d864;text-align:right;'>0.7000</td><td style='color:black;background-color:#d8a564;text-align:right;'>0.3000</td></tr>
# </table><br><center><small><em>posterior HL1</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>HL1</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='text-align:right;'>2.0000</td><td style='text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>posterior Utility HL1</em></small></center></div>

# %%
# UL1T1 utility te berekenen door kansen HL1 en besluit DL1T1 te vermenigvuldigen met utility tabel
.7*1+.3*3
# Out:
# 1.5999999999999999

# %%
# DL1T1 yes waarde is utility .7*1+.3*3 = 1.6
# DL1T1 no waarde is .7*2+.3*0 = 1.4
# Out:
# 3.935

# %%
# HL1 is te berekenen door naar utility te kijken en naar decision te kijken?
# DL1T1 is no dan uit utility tabel de waarden 2 en 0 halen

# %%
# waarden CL1
0.085*

# %%
(.1*2+.9*2)*.7
# Out:
# 1.4

# %%
0.05*2 + 0.95*2
# Out:
# 2.0

# %% [markdown]
# Inference results show "normal operation", no tests are recommended (DT1, DT2, DS1T1)

# %% [markdown]
# ### start diagnosis
# - after startup the system asks to provide evidence on the problem the users are facing
# - the repair specialist enters light 1 is not on
# - the system calculates the most probable situation for the system and derives a next step

# %%
diag.utility("UT1")[{"HL1":"ok", "DT1": "yes"}]     = 1   # test done but not relevant
diag.utility("UT1")[{"HL1":"broken", "DT1": "yes"}] = 3      # test done when broken, excellent
diag.utility("UT1")[{"HL1":"ok", "DT1": "no"}]      = 2    # test not done but that's ok
diag.utility("UT1")[{"HL1":"broken", "DT1": "no"}]  = 0   # test not done when broken: missed chance
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 diag.utility("UT1")[{"HL1":"ok", "DT1": "yes"}]     = 1   # test done but not relevant
#       2 diag.utility("UT1")[{"HL1":"broken", "DT1": "yes"}] = 3      # test done when broken, excellent
#       3 diag.utility("UT1")[{"HL1":"ok", "DT1": "no"}]      = 2    # test not done but that's ok
#
# File ~/.local/lib/python3.11/site-packages/pyAgrum/pyAgrum.py:24859, in InfluenceDiagram.utility(self, *args)
#   24840 def utility(self, *args) -> "pyAgrum.Potential":
#   24841     r"""
#   24842
#   24843     Parameters
#    (...)
#   24857
#   24858     """
# > 24859     return _pyAgrum.InfluenceDiagram_utility(self, *args)
#
# NotFound: [pyAgrum] Object not found: No element with the key <UT1>

# %%
# calculate situation given evidence: light 1 is off
ie = gum.ShaferShenoyLIMIDInference(diag) 
ie.addNoForgettingAssumption(["DT1","DT2", "DRL1"])
gnb.showInference(diag, engine=ie, evs={"CL1":1}, size=15)

# %% [markdown]
# - Inference of the situation with provided evidence "light 1 is off" indicates a higher change light 1 is broken, via the L1H variable. This leads the system to suggest to execute test 1, via a >50% chance for decision DT1 = "Yes".
# - Based on this result the repair specialist is instructed to execute test 1.
# - Test 1 is the cheapest of the tests that can be done to check the health of light 1.

# %% [markdown]
# ### Test 1 performed
# - As instructed the repair specialist executes test 1 and provides the result to the system.
# - The result of test 1 is evidence that indicates light 1 is probably broken.
# - the system is asked for the next step

# %%
diag.utility("UT2")[{"RT1":"not done", "DT2": "yes"}]     = 2   # test done but not relevant
diag.utility("UT2")[{"RT1":"not done", "DT2": "no"}]      = 4   # test not done but not relevant
diag.utility("UT2")[{"RT1":"ok", "DT2": "yes"}]           = 0   # test done but not relevant
diag.utility("UT2")[{"RT1":"ok", "DT2": "no"}]            = 3   # test not done but that's ok
diag.utility("UT2")[{"RT1":"broken", "DT2": "yes"}]       = 5   # test done when broken, excellent
diag.utility("UT2")[{"RT1":"broken", "DT2": "no"}]        = 2   # test not done when broken: missed chance

# %%
diag.utility("UT2")[{"RT1":"not done", "DT2": "yes"}]     = 1   # test done but not relevant
diag.utility("UT2")[{"RT1":"ok", "DT2": "yes"}]           = 0   # test done but not relevant
diag.utility("UT2")[{"RT1":"broken", "DT2": "yes"}]       = 3   # test done when broken, excellent
diag.utility("UT2")[{"RT1":"not done", "DT2": "no"}]      = 2   # test not done but not relevant
diag.utility("UT2")[{"RT1":"ok", "DT2": "no"}]            = 3   # test not done but that's ok
diag.utility("UT2")[{"RT1":"broken", "DT2": "no"}]        = 2   # test not done when broken: missed chance

# %%
# calculate situation given evidencce light 1 is off and test 1 indicate light is broken
ie = gum.ShaferShenoyLIMIDInference(diag) 
ie.addNoForgettingAssumption(["DT1","DT2", "DRL1"])
gnb.showInference(diag, engine=ie, evs={"CL1":1, "RT1": 1}, size=15)

# %%
diag.utility("UT2")

# %% [markdown]
# - Results show a second test is recommended by the system, via decision DT2.
# - The system instructs the repair specialist to execute test 2.

# %% [markdown]
# ### Test 2 performed
# - repair specialist excutes test 2 and provides result to the system.
# - the evidence is the light is definitely broken.

# %%
diag.utility("URL1")[{"RT2":"not done", "DRL1": "replace"}]    = 2   # test done but not relevant
diag.utility("URL1")[{"RT2":"not done", "DRL1": "keep"}]       = 4   # test not done but that's ok
diag.utility("URL1")[{"RT2":"ok", "DRL1": "replace"}]          = 0   # test done but not relevant
diag.utility("URL1")[{"RT2":"ok", "DRL1": "keep"}]             = 3   # test not done but that's ok
diag.utility("URL1")[{"RT2":"broken", "DRL1": "replace"}]      = 4   # test done when broken, excellent
diag.utility("URL1")[{"RT2":"broken", "DRL1": "keep"}]         = 4   # test not done when broken: missed chance

# %%
# calculate situation given evidencce light 1 is off, test 1 & test 2 indicate light is broken
ie = gum.ShaferShenoyLIMIDInference(diag) 
ie.addNoForgettingAssumption(["DT1","DT2", "DRL1"])
gnb.showInference(diag, engine=ie, evs={"CL1":1, "RT1": 2, "RT2": 2}, size=15)

# %% [markdown]
# - Given the results the system now instructs the repair specialist to replace the light, based on result of RT2.
# - The repair specialist is asked to confirm the light is replaced.

# %% [markdown]
# ### new starting point after replacement of light 1

# %%
# inference after light 1 is replaced, chance of failure of light 1 is now between 80/90%
ie = gum.ShaferShenoyLIMIDInference(diag) 
ie.addNoForgettingAssumption(["DT1","DT2", "DRL1", "DST1"])
gnb.showInference(diag, engine=ie, evs={"HL1":[0.99, 0.01],"CL1":1}, size=15)

# %% [markdown]
# - Repair specialist is asked if system is running as expected and this is confirmed.
