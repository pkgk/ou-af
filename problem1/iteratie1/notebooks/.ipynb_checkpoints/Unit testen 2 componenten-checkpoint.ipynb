# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import re
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from IPython.display import display, HTML, clear_output, Image
import pandas as pd
from itertools import product
import math

# Styling notebook
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML("<style>" + styles + "</style")

css_styling()
display(HTML("<style>.container { width:100% !important; }</style>"))
sys.path.insert(1, "/workspaces/ou-af/problem1/iteratie1")

# import de code
import src.system as system
import src.diagrambuilder as builder
import specs.components as componentspecs
import specs.connections as connectionspecs
import specs.assemblies as assemblyspecs
import specs.tests as testspecs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>

# %%
def visualizeStructure(diagram):
#    display(HTML("<style>.container { width:100% !important; }</style>"))

    # print summary of nodes
    print(diagram)

    # view structure
    gnb.showInfluenceDiagram(diagram, size=60)
    
def createUtilityRow(nodelist):
    row_elements = [diagram.utility(node) for node in nodelist]
    gnb.flow.row(*row_elements)

def createCptRow(nodelist):
    row_elements = [diagram.cpt(node) for node in nodelist]
    gnb.flow.row(*row_elements)

def showCPTs(diagram):
    nodes = diagram.nodes()
    for n in nodes:
        if(diagram.isChanceNode(n)):
            gnb.flow.row(diagram.cpt(n))
            
def getDiagramChanceNodeIdsForComponent(componentname, diagram):
    idlist = []
    diagramNames = diagram.names()
    for dname in diagramNames:
        if(re.search(componentname + "$", dname)):
            nodeid = diagram.idFromName(dname)
            if (diagram.isChanceNode(nodeid)):
                idlist.append(nodeid)
    return idlist
    

def printCptTables(diagram, system):
    for component in system.getComponents():
        print("CPT tables for component: " + component.getName())
        createCptRow(getDiagramChanceNodeIdsForComponent(component.getName(), diagram))
        
def getDiagramUtilityNodeIdsForComponent(componentname, diagram):
    idlist = []
    diagramNames = diagram.names()
    for dname in diagramNames:
        if(re.search(componentname + "$", dname)):
            nodeid = diagram.idFromName(dname)
            if (diagram.isUtilityNode(nodeid)):
                idlist.append(nodeid)
    return idlist
    

def printUtilityTables(diagram, system):
    for component in system.getComponents():
        print("Utility tables for component: " + component.getName())
        createUtilityRow(getDiagramUtilityNodeIdsForComponent(component.getName(), diagram))

# %%
# gather specs for a system
# system = light + replacedecision + test
components = [componentspecs.light, componentspecs.switch]
connections = [connectionspecs.wire, connectionspecs.wire2]
tests = [testspecs.testObserveHealth]
assembly = {
    "components"  : components,
    "connections" : connections,
    "structure"   : assemblyspecs.structure1,
    "tests"       : tests,
    "testmapping" : testspecs.testmapping2
}

# read specifications, create system of objects
system = system.createSystemFromSpecs(assembly)

# create diagram object
diagram = gum.InfluenceDiagram()

diagram = builder.diagramBuilder(diagram, system)

# view structure
gnb.showInfluenceDiagram(diagram, size=100)
# Out:
# building system: structure1
# number of components: 2
# number of connections: 1
# number of tests: 2
# adding component: Light
# adding component: Switch
# adding connection between: PresentPowerOutputsSwitch and: PresentPowerInputsLight
# adding cpt for component: Light
# adding cpt for component: Switch
# adding cpt for connection: Wire
# adding Replace decision for component: Light
# adding Replace decision for component: Switch
# adding Replace utility for component: Light
# adding Replace utility for component: Switch
# adding test: TestObserveHealth to component: Light
# adding test: TestObserveHealth to component: Switch

# %%
diagram.addArc('TestOutcomeTestObserveHealthSwitch', "DecisionReplaceSwitch")
diagram.addArc('TestOutcomeTestObserveHealthLight', "DecisionReplaceLight")

# %%
gnb.showInfluenceDiagram(diagram, size=100)

# %%
gnb.flow.row(
diagram.utility("UtilityTestObserveHealthSwitch"),
diagram.utility("UtilityTestObserveHealthLight"),
diagram.utility("UtilityReplaceSwitch"),
diagram.utility("UtilityReplaceLight")
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UtilityTestObserveHealthSwitch</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionTestObserveHealthSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-1.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UtilityTestObserveHealthLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionTestObserveHealthLight</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-1.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UtilityReplaceSwitch</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionReplaceSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-5.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-2.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>-4.0000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UtilityReplaceLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthLight</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionReplaceLight</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-5.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-2.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>-4.0000</td></tr>
# </table></div>

# %%
gnb.flow.row(diagram.cpt("healthSwitch"),
             diagram.cpt("healthLight"),
             diagram.cpt("healthWire")
            )
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthSwitch</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthLight</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthWire</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div>

# %%
diagram.cpt("TestOutcomeTestObserveHealthLight")[0] = [[0.998, 0.001, 0.001], [0.001, 0.001, 0.998]]
diagram.cpt("TestOutcomeTestObserveHealthLight")[1] = [[0.001, 0.998, 0.001], [0.001, 0.001, 0.998]]

diagram.cpt("TestOutcomeTestObserveHealthSwitch")[0] = [[0.998, 0.001, 0.001], [0.001, 0.001, 0.998]]
diagram.cpt("TestOutcomeTestObserveHealthSwitch")[1] = [[0.001, 0.998, 0.001], [0.001, 0.001, 0.998]]

# %%
gnb.flow.row(diagram.cpt("TestOutcomeTestObserveHealthLight"),
            diagram.cpt("TestOutcomeTestObserveHealthSwitch"))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>TestOutcomeTestObserveHealthLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthLight</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionTestObserveHealthLight</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>notdone</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>TestOutcomeTestObserveHealthSwitch</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionTestObserveHealthSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>notdone</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0010</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9980</td></tr>
# </table></div>

# %%
gnb.flow.row(diagram.cpt("PresentLightOutputsLight"),
            diagram.cpt("PresentPowerInputsLight"),
            diagram.cpt("PresentPowerOutputsSwitch")
            )
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentLightOutputsLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthLight</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputsLight</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentPowerInputsLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthWire</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerOutputsSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentPowerOutputsSwitch</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>EnabledStateInputsSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputsSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-colo

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,
    
#'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':0,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.cpt("healthWire")[0] = 0.95
diagram.cpt("healthWire")[1] = 0.05

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,
    
#'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':0,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.cpt("healthSwitch")[0] = 0.95
diagram.cpt("healthSwitch")[1] = 0.05
diagram.cpt("healthWire")[0] = 0.99
diagram.cpt("healthWire")[1] = 0.01

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,
    
#'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':0,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.cpt("healthSwitch")[0] = 0.90
diagram.cpt("healthSwitch")[1] = 0.1
diagram.cpt("healthWire")[0] = 0.95
diagram.cpt("healthWire")[1] = 0.05

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,
    
#'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':0,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.cpt("healthLight")[0] = 0.9
diagram.cpt("healthLight")[1] = 0.1
diagram.cpt("healthSwitch")[0] = 0.95
diagram.cpt("healthSwitch")[1] = 0.05
diagram.cpt("healthWire")[0] = 0.99
diagram.cpt("healthWire")[1] = 0.01

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,
    
#'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':0,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
evs = {
'PresentLightOutputsLight':1,

'PresentPowerInputsLight':1,
    
'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':1,
'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.cpt("healthLight")[0] = 0.99
diagram.cpt("healthLight")[1] = 0.01
diagram.cpt("healthSwitch")[0] = 0.99
diagram.cpt("healthSwitch")[1] = 0.01
diagram.cpt("healthWire")[0] = 0.99
diagram.cpt("healthWire")[1] = 0.01

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,

#'PresentPowerOutputsSwitch':0,
#'PresentPowerInputsSwitch':1,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.getDecisionGraph()
# Out:
# (pyAgrum.DAG@0x3e09ae00) {8,10,12,15} , {12->8,15->10}

# %%
diagram.decisionOrderExists()
# Out:
# False

# %%
ie = gum.ShaferShenoyLIMIDInference(diagram) 
ie.setEvidence(evs)
ie.addNoForgettingAssumption(["DecisionTestObserveHealthSwitch","DecisionReplaceSwitch", "DecisionTestObserveHealthLight", "DecisionReplaceLight"])
gnb.sideBySide(gnb.getInference(diagram,engine=ie, evs=evs, size=200))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1488pt" height="497pt" viewBox="0.00 0.00 1487.87 496.82">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 492.82)">
# <title>structs</title>
# <text text-anchor="middle" x="739.94" y="-22.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU -1.62 (stdev=2.28)</text>
# <text text-anchor="middle" x="739.94" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.53ms</text>
# <!-- PresentLightOutputsLight -->
# <g id="node1" class="node">
# <title>PresentLightOutputsLight</title>
# <polygon fill="none" stroke="#000000" points="845.11,-239.82 696.11,-239.82 696.11,-197.82 845.11,-197.82 845.11,-239.82"/>
# <svg viewBox="0 0 196.95125 53.538125" width="149px" height="42px" preserveAspectRatio="xMinYMin meet" x="696.111" y="-239.825"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-02-18T15:39:43.502359</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 53.538125  L 196.95125 53.538125  L 196.95125 0  L 0 0  z " style="fill: #f4a460"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 61.128125 46.438125  L 172.728125 46.438125  L 172.728125 18.718125  L 61.128125 18.718125  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 61.128125 46.438125  L 172.728125 46.438125  L 172.728125 34.118125  L 61.128125 34.118125  z " clip-path="url(#p4c75e0c621)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 61.128125 31.038125  L 61.128125 31.038125  L 61.128125 18.718125  L 61.128125 18.718125  z " clip-path="url(#p4c75e0c621)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 61.128125 46.438125  L 61.128125 18.718125  " clip-path="url(#p4c75e0c621)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="mcce2978983" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#mcce2978983" x="61.128125" y="46.438125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 116.928125 46.438125  L 116.928125 18.718125  " clip-path="url(#p4c75e0c621)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#mcce2978983" x="116.928125" y="46.438125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 172.728125 46.438125  L 172.728125 18.718125  " clip-path="url(#p4c75e0c621)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#mcce2978983" x="172.728125" y="46.438125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path id="mc40dd17e3a" d="M 0 0  L -3.5 0  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#mc40dd17e3a" x="61.128125" y="40.278125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- no [-1.62] -->
#       <g transform="translate(4.817188 44.077344) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-6e" d="M 3513 2113  L 3513 0  L 2938 0  L 2938 2094  Q 2938 2591 2744 2837  Q 2550 3084 2163 3084  Q 1697 3084 1428 2787  Q 1159 2491 1159 1978  L 1159 0  L 581 0  L 581 3500  L 1159 3500  L 1159 2956  Q 1366 3272 1645 3428  Q 1925 3584 2291 3584  Q 2894 3584 3203 3211  Q 3513 2838 3513 2113  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-6f" d="M 1959 3097  Q 1497 3097 1228 2736  Q 959 2375 959 1747  Q 959 1119 1226 758  Q 1494 397 1959 397  Q 2419 397 2687 759  Q 2956 1122 2956 1747  Q 2956 2369 2687 2733  Q 2419 3097 1959 3097  z M 1959 3584  Q 2709 3584 3137 3096  Q 3566 2609 3566 1747  Q 3566 888 3137 398  Q 2709 -91 1959 -91  Q 1206 -91 779 398  Q 353 888 353 1747  Q 353 2609 779 3096  Q 1206 3584 1959 3584  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-20" transform="scale(0.015625)"/>
#         <path id="DejaVuSans-5b" d="M 550 4863  L 1875 4863  L 1875 4416  L 1125 4416  L 1125 -397  L 1875 -397  L 1875 -844  L 550 -844  L 550 4863  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2d" d="M 313 2009  L 1997 2009  L 1997 1497  L 313 1497  L 313 2009  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-36" d="M 2113 2584  Q 1688 2584 1439 2293  Q 1191 2003 1191 1497  Q 1191 994 1439 701  Q 1688 409 2113 409  Q 2538 409 2786 701  Q 3034 994 3034 1497  Q 3034 2003 2786 2293  Q 2538 2584 2113 2584  z M 3366 4563  L 3366 3988  Q 3128 4100 2886 4159  Q 2644 4219 2406 4219  Q 1781 4219 1451 3797  Q 1122 3375 1075 2522  Q 1259 2794 1537 2939  Q 1816 3084 2150 3084  Q 2853 3084 3261 2657  Q 3669 2231 3669 1497  Q 3669 778 3244 343  Q 2819 -91 2113 -91  Q 1303 -91 875 529  Q 447 1150 447 2328  Q 447 3434 972 4092  Q 1497 4750 2381 4750  Q 2619 4750 2861 4703  Q 3103 4656 3366 4563  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-32" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#         <path id="DejaVuSans-5d" d="M 1947 4863  L 1947 -844  L 622 -844  L 622 -397  L 1369 -397  L 1369 4416  L 622 4416  L 622 4863  L 1947 4863  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-6e"/>
#        <use xlink:href="#DejaVuSans-6f" x="63.378906"/>
#        <use xlink:href="#DejaVuSans-20" x="124.560547"/>
#        <use xlink:href="#DejaVuSans-5b" x="156.347656"/>
#        <use xlink:href="#DejaVuSans-2d" x="195.361328"/>
#        <use xlink:href="#DejaVuSans-31" x="231.445312"/>
#        <use xlink:href="#DejaVuSans-2e" x="295.068359"/>
#        <use xlink:href="#DejaVuSans-36" x="326.855469"/>
#        <use xlink:href="#DejaVuSans-32" x="390.478516"/>
#        <use xlink:href="#DejaVuSans-5d" x="454.101562"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#mc40dd17e3a" x="61.128125" y="24.878125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- yes [0.00] -->
#       <g transform="translate(3.6 28.677344) scale(0.1 -0.1)">
#        <de

# %%
gnb.showInfluenceDiagram(ie.reducedLIMID(), size=100)

# %%
ie.reducedLIMID().decisionOrderExists()
# Out:
# False

# %%
diagram.addArc("DecisionReplaceSwitch", "DecisionTestObserveHealthLight")

# %%
gnb.showInfluenceDiagram(diagram, size=100)

# %%
diagram.cpt("healthLight")[0] = 0.9
diagram.cpt("healthLight")[1] = 0.1
diagram.cpt("healthSwitch")[0] = 0.95
diagram.cpt("healthSwitch")[1] = 0.05
diagram.cpt("healthWire")[0] = 0.99
diagram.cpt("healthWire")[1] = 0.01

# %%
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[0,0] = -5  # health:ok, decision:yes
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[0,1] = 0   # health:ok, decision:no
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[1,0] = -2 # health:broken, decision:yes  
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[1,1] = -4  # health:broken, decision:no

# %%
diagram.utility(diagram.idFromName("UtilityReplaceLight"))
# Out:
# (pyAgrum.Potential<double>@0x3d1b7ba0)
#              ||  Utility|
# Decisi|health||0        |
# ------|------||---------|
# yes   |ok    || -5.0000 |
# no    |ok    || 0.0000  |
# yes   |broken|| -2.0000 |
# no    |broken|| -4.0000 |

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':1,

'PresentPowerOutputsSwitch':0,
'PresentPowerInputsSwitch':1,
'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)

# %%
diagram.getDecisionGraph()
# Out:
# (pyAgrum.DAG@0x3e4fbe10) {8,10,12,15} , {10->12,12->8,15->10}

# %%
# first run first cell of this notebook
# gather specs for a system
# system = light + replacedecision + test
components = [componentspecs.light, componentspecs.switch]
connections = [connectionspecs.wire, connectionspecs.wire2]
tests = [testspecs.testObserveHealth]
assembly = {
    "components"  : components,
    "connections" : connections,
    "structure"   : assemblyspecs.structure1,
    "tests"       : tests,
    "testmapping" : testspecs.testmapping4
}

# read specifications, create system of objects
system = system.createSystemFromSpecs(assembly)

# create diagram object
diagram = gum.InfluenceDiagram()

diagram = builder.diagramBuilder(diagram, system)

# view structure
gnb.showInfluenceDiagram(diagram, size=100)
# Out:
# building system: structure1
# number of components: 2
# number of connections: 1
# number of tests: 0
# adding component: Light
# adding component: Switch
# adding connection between: PresentPowerOutputsSwitch and: PresentPowerInputsLight
# adding cpt for component: Light
# adding cpt for component: Switch
# adding cpt for connection: Wire
# adding Replace decision for component: Light
# adding Replace decision for component: Switch
# adding Replace utility for component: Light
# adding Replace utility for component: Switch

# %%
gnb.flow.row(
#diagram.utility("UtilityTestObserveHealthSwitch"),
#diagram.utility("UtilityTestObserveHealthLight"),
diagram.utility("UtilityReplaceSwitch"),
diagram.utility("UtilityReplaceLight")
) 

gnb.flow.row(diagram.cpt("healthSwitch"),
             diagram.cpt("healthLight"),
             diagram.cpt("healthWire")
            )

#diagram.cpt("TestOutcomeTestObserveHealthLight")[0] = [[0.998, 0.001, 0.001], [0.001, 0.001, 0.998]]
#diagram.cpt("TestOutcomeTestObserveHealthLight")[1] = [[0.001, 0.998, 0.001], [0.001, 0.001, 0.998]]

#diagram.cpt("TestOutcomeTestObserveHealthSwitch")[0] = [[0.998, 0.001, 0.001], [0.001, 0.001, 0.998]]
#diagram.cpt("TestOutcomeTestObserveHealthSwitch")[1] = [[0.001, 0.998, 0.001], [0.001, 0.001, 0.998]]

#gnb.flow.row(diagram.cpt("TestOutcomeTestObserveHealthLight"),
#            diagram.cpt("TestOutcomeTestObserveHealthSwitch"))

gnb.flow.row(diagram.cpt("PresentLightOutputsLight"),
            diagram.cpt("PresentPowerInputsLight"),
            diagram.cpt("PresentPowerOutputsSwitch")
            )
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UtilityReplaceSwitch</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionReplaceSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-5.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-2.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>-4.0000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>UtilityReplaceLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthLight</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>DecisionReplaceLight</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-5.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>-2.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>-4.0000</td></tr>
# </table></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthSwitch</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthLight</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthWire</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentLightOutputsLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthLight</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputsLight</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentPowerInputsLight</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthWire</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerOutputsSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentPowerOutputsSwitch</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>EnabledStateInputsSwitch</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputsSwitch</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-color:#7ffe64;text-align:right;'>0.9999</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0001</td><td style='color:black;background-colo

# %%
diagram.cpt("healthLight")[0] = 0.9
diagram.cpt("healthLight")[1] = 0.1
diagram.cpt("healthSwitch")[0] = 0.95
diagram.cpt("healthSwitch")[1] = 0.05
diagram.cpt("healthWire")[0] = 0.99
diagram.cpt("healthWire")[1] = 0.01

# %%
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[0,0] = -50  # health:ok, decision:yes
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[0,1] = 0   # health:ok, decision:no
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[1,0] = -20 # health:broken, decision:yes  
diagram.utility(diagram.idFromName("UtilityReplaceLight"))[1,1] = -40  # health:broken, decision:no

# %%
evs = {
'PresentLightOutputsLight':1,

#'PresentPowerInputsLight':0,

#'PresentPowerOutputsSwitch':1,
#'PresentPowerInputsSwitch':0,
#'EnabledStateInputsSwitch':0,

# 'DecisionReplaceLight':,
# 'DecisionReplaceSwitch':,
# 'DecisionTestObserveHealthLight':,
# 'DecisionTestObserveHealthSwitch':,

# 'TestOutcomeTestObserveHealthLight':,
# 'TestOutcomeTestObserveHealthSwitch':,
# 'UtilityReplaceLight':,
# 'UtilityReplaceSwitch':,
# 'UtilityTestObserveHealthLight':,
# 'UtilityTestObserveHealthSwitch':,
# 'healthLight':,
# 'healthSwitch':,
# 'healthWire':
}
gnb.showInference(diagram, evs=evs, size=40)
