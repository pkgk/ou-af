# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import re
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
from IPython.display import display, HTML, clear_output, Image
import pandas as pd
from itertools import product
import math
from deepdiff import DeepDiff

# %%
# Styling notebook
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML("<style>" + styles + "</style")

css_styling()

# %%
sys.path.insert(1, "/workspaces/ou-af/printer/")

# %%
# import de code
import src.oopnclasses as oopnclasses
import src.oopnbuilder as oopnbuilder
import src.diagrambuilder as diagrambuilder
import src.testobservereplace as testchangeinput
import src.testchangeinput as testobservereplace
import specs.components as componentspecs
import specs.connections as connectionspecs
import specs.assemblies as assemblyspecs
import specs.tests as testspecs

# %%
def visualizeStructure(diagram):
#    display(HTML("<style>.container { width:100% !important; }</style>"))

    # print summary of nodes
    print(diagram)

    # view structure
    gnb.showInfluenceDiagram(diagram, size=60)
    
def createUtilityRow(nodelist):
    row_elements = [diagram.utility(node) for node in nodelist]
    gnb.flow.row(*row_elements)

def createCptRow(nodelist):
    row_elements = [diagram.cpt(node) for node in nodelist]
    gnb.flow.row(*row_elements)

def showCPTs(diagram):
    nodes = diagram.nodes()
    for n in nodes:
        if(diagram.isChanceNode(n)):
            gnb.flow.row(diagram.cpt(n))
            
def getDiagramChanceNodeIdsForComponent(componentname, diagram):
    idlist = []
    diagramNames = diagram.names()
    for dname in diagramNames:
        if(re.search(componentname + "$", dname)):
            nodeid = diagram.idFromName(dname)
            if (diagram.isChanceNode(nodeid)):
                idlist.append(nodeid)
    return idlist
    

def printCptTables(diagram, system):
    for component in system.getComponents():
        print("CPT tables for component: " + component.getName())
        createCptRow(getDiagramChanceNodeIdsForComponent(component.getName(), diagram))
        
def getDiagramUtilityNodeIdsForComponent(componentname, diagram):
    idlist = []
    diagramNames = diagram.names()
    for dname in diagramNames:
        if(re.search(componentname + "$", dname)):
            nodeid = diagram.idFromName(dname)
            if (diagram.isUtilityNode(nodeid)):
                idlist.append(nodeid)
    return idlist
    

def printUtilityTables(diagram, system):
    for component in system.getComponents():
        print("Utility tables for component: " + component.getName())
        createUtilityRow(getDiagramUtilityNodeIdsForComponent(component.getName(), diagram))

# %%
# gather specs for a system
# system = light + replacedecision + test
components = [componentspecs.drum, componentspecs.charge_roll, componentspecs.developer_roll, componentspecs.tilted_mirror, componentspecs.lens, componentspecs.wiper]
connections = [connectionspecs.laserbeam, connectionspecs.wipercontact, connectionspecs.rollcontact, connectionspecs.charge, connectionspecs.movingbeam]
tests = [testspecs.changeinputtest]
assembly = {
    "components"  : components,
    "connections" : connections,
    "structure"   : assemblyspecs.printerassembly,   
    "tests"       : tests,
    "testmapping" : testspecs.testmapping4     
}

# %%
# fill information model with network classes based on descriptions
oopn = oopnbuilder.OopnBuilder(assembly).getOopn()
# Out:
# start building system: printer
# number of components: 6
# number of connections: 5
# number of tests: 0

# %%
# create diagram object
diagram = gum.InfluenceDiagram()
diagram = diagrambuilder.diagramBuilder(diagram, oopn)
# Out:
# adding component: wiper
# adding component: lens
# adding component: tilted_mirror
# adding component: developer_roll
# adding component: charge_roll
# adding component: drum
# adding connection between: PresentMovementOutputswiper and: PresentMovementInputsdrum
# adding connection between: PresentFocussedLaserbeamOutputslens and: PresentFocussedLaserbeamInputstilted_mirror
# adding connection between: PresentMovingTonerParticlesOutputsdeveloper_roll and: PresentMovingTonerParticlesInputsdrum
# adding connection between: PresentElectricalChargeOutputscharge_roll and: PresentElectricalChargeInputsdrum
# adding connection between: PresentMovingBeamOutputstilted_mirror and: PresentMovingBeamInputsdrum
# adding cpt for component: wiper
# adding cpt for component: lens
# adding cpt for component: tilted_mirror
# adding cpt for component: developer_roll
# adding cpt for component: charge_roll
# adding cpt for component: drum
# adding cpt for connection: wipercontact
# adding cpt for connection: laserbeam
# adding cpt for connection: rollcontact
# adding cpt for connection: charge
# adding cpt for connection: movingbeam

# %%
gnb.showInfluenceDiagram(diagram, size=100)

# %%
printCptTables(diagram, oopn)
# Out:
# CPT tables for component: wiper
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthwiper</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentMovementOutputswiper</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthwiper</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentControl_signalInputswiper</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputswiper</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>PresentPowerInputswiper</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>PresentControl_signalInputswiper</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div>
# CPT tables for component: lens
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>PresentLaserbeamInputslens</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthlens</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentFocussedLaserbeamOutputslens</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthlens</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentLaserbeamInputslens</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div>
# CPT tables for component: tilted_mirror
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthtilted_mirror</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='4'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentMovingBeamOutputstilted_mirror</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthtilted_mirror</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentControlSignalInputstilted_mirror</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputstilted_mirror</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentFocussedLaserbeamInputstilted_mirror</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '8'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '8'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentFocussedLaserbeamInputstilted_mirror</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthlaserbeam</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentFocussedLaserbeamOutputslens</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='color:black;background
# CPT tables for component: developer_roll
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>PresentPowerInputsdeveloper_roll</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentMovingTonerParticlesOutputsdeveloper_roll</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthdeveloper_roll</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentTonerParticlesInputsdeveloper_roll</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputsdeveloper_roll</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthdeveloper_roll</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>PresentTonerParticlesInputsdeveloper_roll</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div>
# CPT tables for component: charge_roll
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>PresentPowerInputscharge_roll</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>high</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>low</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>healthcharge_roll</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>ok</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>broken</center></th></tr>
# <tr><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentElectricalChargeOutputscharge_roll</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthcharge_roll</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentPowerInputscharge_roll</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>high</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>low</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>high</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>low</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>high</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>low</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div>
# CPT tables for component: drum
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentElectricalChargeInputsdrum</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthcharge</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentElectricalChargeOutputscharge_roll</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>high</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>low</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>high</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>low</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>high</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>low</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentMovementInputsdrum</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthwipercontact</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentMovementOutputswiper</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentMovingBeamInputsdrum</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthmovingbeam</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentMovingBeamOutputstilted_mirror</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>broken</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.9900</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='5'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>PresentImageInTonerOutputsdrum</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>healthdrum</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentElectricalChargeInputsdrum</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentMovingTonerParticlesInputsdrum</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentMovingBeamInputsdrum</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PresentMovementInputsdrum</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>no</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '16'>
#             <center>ok</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '8'>
#             <center>high</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>yes</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.9900</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>no</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>yes</center></th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>no</center></th><td style='text

# %%
evs = {    
'PresentPowerInputsSwitch':0,
'EnabledStateInputsSwitch':0,

'PresentLightOutputsLight':1,
#'PresentPowerInputsLight',
#'healthLight',
#'PresentPowerOutputsSwitch',
#'healthSwitch',
#'PresentLightOutputsLight1',
#'PresentPowerInputsLight1':1,
#'healthLight1',
#'PresentPowerOutputsSwitch1',
#'PresentPowerInputsSwitch1',
#'EnabledStateInputsSwitch1',
#'healthSwitch1',
#'PresentLightOutputsLight2':1,
#'PresentPowerInputsLight2',
#'healthLight2',
#'PresentPowerOutputsSwitch2',
#'PresentPowerInputsSwitch2',
#'EnabledStateInputsSwitch2',
#'healthSwitch2',
#'healthLight1',
#'EnabledStateInputsSwitch2',
#'healthSwitch2',
#'healthLight2',
}

# %%
evs2 = {    
'PresentPowerInputsSwitch':0,
'EnabledStateInputsSwitch':0,

'PresentLightOutputsLight':1,
#'PresentPowerInputsLight',
#'healthLight',
#'PresentPowerOutputsSwitch',
#'healthSwitch',
#'PresentLightOutputsLight1',
#'PresentPowerInputsLight1':1,
#'healthLight1',
#'PresentPowerOutputsSwitch1',
#'PresentPowerInputsSwitch1',
#'EnabledStateInputsSwitch1',
#'healthSwitch1',
#'PresentLightOutputsLight2':1,
#'PresentPowerInputsLight2',
#'healthLight2',
#'PresentPowerOutputsSwitch2',
#'PresentPowerInputsSwitch2',
#'EnabledStateInputsSwitch2',
#'healthSwitch2',
#'healthLight1',
#'PresentLightOutputsLight1copy':0,
#'PresentPowerInputsLight1copy':0,
#'EnabledStateInputsSwitch2',
#'healthSwitch2',
#'PresentPowerOutputsSwitch2copy',
'PresentPowerInputsSwitchcopy':1,
#'healthLight2',
'PresentLightOutputsLightcopy':0,
#'PresentPowerInputsLight2copy':1
}

# %%
ie = gum.ShaferShenoyLIMIDInference(diagram) 
ie.setEvidence(evs)
#ie.addNoForgettingAssumption(["DecisionTestObserveHealthSwitch","DecisionReplaceSwitch", "DecisionTestObserveHealthLight", "DecisionReplaceLight"])
gnb.sideBySide(gnb.getInference(diagram,engine=ie, evs=evs, size=200))

# %%
ie2 = gum.ShaferShenoyLIMIDInference(diagram2) 
ie2.setEvidence(evs2)
#ie.addNoForgettingAssumption(["DecisionTestObserveHealthSwitch","DecisionReplaceSwitch", "DecisionTestObserveHealthLight", "DecisionReplaceLight"])
gnb.sideBySide(gnb.getInference(diagram2,engine=ie2, evs=evs2, size=200))

# %%
# visualiseren additionele DAG 
import matplotlib.pyplot as plt
subax1 = plt.subplot()
#nx.draw(G, with_labels=True, font_color='white', node_size=2000)
nx.draw(G, font_color='white', node_size=500)

# %%
# outputtest
testutility = diagram.addUtilityNode(gum.LabelizedVariable("outputTest", "outputTest", 1))
testdecision = diagram.addDecisionNode(gum.LabelizedVariable("testdecision", "testdecisionl", ["yes", "no"]))
testoutcome = diagram.addChanceNode(gum.LabelizedVariable("testoutcome", "testoutcome", ["ok", "problem", "notdone"]))
diagram.addArc(diagram.idFromName("PresentLightOutputsLight"), testutility)
diagram.addArc(testdecision, testutility)
diagram.addArc(testdecision, testoutcome)
diagram.addArc(diagram.idFromName("healthWire"), testoutcome)
diagram.addArc(diagram.idFromName("healthSwitch"), testoutcome)
diagram.addArc(diagram.idFromName("healthLight"), testoutcome)

# %%
printCptTables(diagram, oopn)

# %%
printUtilityTables(diagram, oopn)

# %%
diagram.utility("outputTest")[{"testdecision":"yes", "PresentLightOutputsLight":"no"}] = 4
diagram.utility("outputTest")[{"testdecision":"no", "PresentLightOutputsLight":"no"}] = 3
diagram.utility("outputTest")[{"testdecision":"yes", "PresentLightOutputsLight":"yes"}] = 2
diagram.utility("outputTest")[{"testdecision":"no", "PresentLightOutputsLight":"yes"}] = 1
diagram.utility("outputTest")

# %%
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"ok", "healthWire":"ok","testdecision":"yes" }] = [0.98, 0.01, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"ok", "healthWire":"ok","testdecision":"no" }] = [0.01, 0.01, 0.98]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"ok", "healthWire":"broken","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"ok", "healthWire":"broken","testdecision":"no" }] = [0.01, 0.01, 0.98]

diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"broken", "healthWire":"ok","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"broken", "healthWire":"ok","testdecision":"no" }] = [0.01, 0.01, 0.98]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"broken", "healthWire":"broken","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"ok", "healthSwitch":"broken", "healthWire":"broken","testdecision":"no" }] = [0.01, 0.01, 0.98]

diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"ok", "healthWire":"ok","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"ok", "healthWire":"ok","testdecision":"no" }] = [0.01, 0.01, 0.98]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"ok", "healthWire":"broken","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"ok", "healthWire":"broken","testdecision":"no" }] = [0.01, 0.01, 0.98]

diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"broken", "healthWire":"ok","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"broken", "healthWire":"ok","testdecision":"no" }] = [0.01, 0.01, 0.98]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"broken", "healthWire":"broken","testdecision":"yes" }] = [0.01, 0.98, 0.01]
diagram.cpt(diagram.idFromName("testoutcome"))[{"healthLight":"broken", "healthSwitch":"broken", "healthWire":"broken","testdecision":"no" }] = [0.01, 0.01, 0.98]

# %%
diagram.cpt(diagram.idFromName("testoutcome"))

# %%
diagram.cpt.posterior("outputTest")

# %%
ie.posteriorUtility("UtilityReplaceWire")

# %%
a = -5*.0087 + -2*.0013
b = 0 + -4* .1238
print(a+b)

# %%
gnb.showInfluenceDiagram(diagram, size=60)

# %%
from collections import defaultdict, deque

# Class to represent a graph using adjacency list


class Graph:
    def __init__(self):
        self.adjList = defaultdict(list)

    # Function to add an edge to the graph
    def addEdge(self, u, v):
        self.adjList[u].append(v)

    # Function to perform Breadth First Search on a graph represented using adjacency list
    def bfs(self, startNode):
        # Create a queue for BFS
        queue = deque()
        visited = [False] * (max(self.adjList.keys()) + 1)

        # Mark the current node as visited and enqueue it
        visited[startNode] = True
        queue.append(startNode)

        # Iterate over the queue
        while queue:
            # Dequeue a vertex from queue and print it
            currentNode = queue.popleft()
            print(currentNode, end=" ")

            # Get all adjacent vertices of the dequeued vertex currentNode
            # If an adjacent has not been visited, then mark it visited and enqueue it
            for neighbor in self.adjList[currentNode]:
                if not visited[neighbor]:
                    visited[neighbor] = True
                    queue.append(neighbor)


# Create a graph
graph = Graph()

# Add edges to the graph
graph.addEdge(0, 1)
graph.addEdge(0, 2)
graph.addEdge(1, 3)
graph.addEdge(1, 4)
graph.addEdge(2, 4)

# Perform BFS traversal starting from vertex 0
print("Breadth First Traversal starting from vertex 0:", end=" ")
graph.bfs(0)

# %%
import networkx as nx

G = nx.DiGraph()
G.add_nodes_from(range(100, 105))
G.add_edges_from([(100, 101), (100, 103), (101,104), (103,102)])

# %%
import matplotlib.pyplot as plt
subax1 = plt.subplot()
nx.draw(G, with_labels=True, font_weight='bold', font_color='white', node_size=1000)

# %%
nx.has_path(G, 100, 104)

# %%
nx.shortest_path(G, 100, 104)

# %%
nx.has_path(G, 100, 104)
nx.shortest_path(G, 100, 104)
